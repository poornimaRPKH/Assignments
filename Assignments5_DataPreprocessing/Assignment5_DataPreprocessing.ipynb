# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/GeethaGunasekaran1/Dataset_rep/refs/heads/main/diabetes.csv"

df = pd.read_csv(url)
df.to_csv("diabetes.csv", index=False)
print("File downloaded successfully!")
# Out:
# File downloaded successfully!

# %%
import pandas as pd

df = pd.read_csv("diabetes.csv")

print(df.head())
# Out:
#    Unnamed: 0   ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  \
# 0           0  502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 1           1  735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1
# 2           2  420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 3           3  680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 4           4  504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8
#
#    LDL  VLDL   BMI CLASS
# 0  1.4   0.5  24.0     N
# 1  2.1   0.6  23.0     N
# 2  1.4   0.5  24.0     N
# 3  1.4   0.5  24.0     N
# 4  2.0   0.4  21.0     N

# %%
# Load Dataset
df = pd.read_csv("diabetes.csv")
#url = "https://raw.githubusercontent.com/GeethaGunasekaran1/Dataset_rep/refs/heads/main/diabetes.csv"
#df = pd.read_csv(url)
print(df.head())
# Out:
#    Unnamed: 0   ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  \
# 0           0  502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 1           1  735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1
# 2           2  420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 3           3  680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 4           4  504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8
#
#    LDL  VLDL   BMI CLASS
# 0  1.4   0.5  24.0     N
# 1  2.1   0.6  23.0     N
# 2  1.4   0.5  24.0     N
# 3  1.4   0.5  24.0     N
# 4  2.0   0.4  21.0     N

# %%
#Verify the Dataset Loaded
print("Dataset Loaded Successfully!")
print(df.head())
# Out:
# Dataset Loaded Successfully!
#    Unnamed: 0   ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  \
# 0           0  502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 1           1  735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1
# 2           2  420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 3           3  680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 4           4  504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8
#
#    LDL  VLDL   BMI CLASS
# 0  1.4   0.5  24.0     N
# 1  2.1   0.6  23.0     N
# 2  1.4   0.5  24.0     N
# 3  1.4   0.5  24.0     N
# 4  2.0   0.4  21.0     N

# %%
# Load Dataset
df = pd.read_csv("diabetes.csv")

# First 5 rows
print("HEAD")
print(df.head())

# Last 5 rows
print("\nTAIL")
print(df.tail())

# Shape
print("\nSHAPE")
print(df.shape)

# Columns
print("\nCOLUMNS")
print(df.columns)

# Info
print("\nINFO")
print(df.info())

# Data Types
print("\nDATA TYPES")
print(df.dtypes)



# Categorical Columns
categorical_cols = ['Gender', 'CLASS']

print("\nCATEGORICAL COLUMNS")
print(categorical_cols)
# Numerical Columns
numerical_cols = df.select_dtypes(include=['number']).columns

print("NUMERICAL COLUMNS")
print(list(numerical_cols))
# Out:
# HEAD
#    Unnamed: 0   ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  \
# 0           0  502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 1           1  735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1
# 2           2  420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 3           3  680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 4           4  504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8
#
#    LDL  VLDL   BMI CLASS
# 0  1.4   0.5  24.0     N
# 1  2.1   0.6  23.0     N
# 2  1.4   0.5  24.0     N
# 3  1.4   0.5  24.0     N
# 4  2.0   0.4  21.0     N
#
# TAIL
#       Unnamed: 0   ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  \
# 1004        1004  194     454316      F  57.0   4.1  70.0    9.3   5.3  3.3
# 1005        1005  195       4543      f  55.0   4.1  34.0   13.9   5.4  1.6
# 1006        1006  249      48822      M  55.0   4.2  57.0    8.9   5.3  3.1
# ...

# %% [markdown]
# # TASK 2 – DATA CLEANING

# %%
# 1. Rename Columns

print("Before Renaming:")
print(df.columns)

df.rename(columns={
'ID':'Visit_ID',
'No_Pation':'Patient_ID'
}, inplace=True)

print("\nAfter Renaming:")
print(df.columns)
# Out:
# Before Renaming:
# Index(['Unnamed: 0', 'ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c',
#        'Chol', 'TG', 'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='str')
#
# After Renaming:
# Index(['Unnamed: 0', 'Visit_ID', 'Patient_ID', 'Gender', 'AGE', 'Urea', 'Cr',
#        'HbA1c', 'Chol', 'TG', 'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='str')

# %%
#Check Unique Values in Categorical Columns

print("\nUnique Values in Gender:")
print(df['Gender'].unique())

print("\nUnique Values in CLASS:")
print(df['CLASS'].unique())
# Out:
# Unique Values in Gender:
# <StringArray>
# ['F', 'M', nan, 'f']
# Length: 4, dtype: str
#
# Unique Values in CLASS:
# <StringArray>
# ['N', 'N ', 'P', 'Y', 'Y ']
# Length: 5, dtype: str

# %%
#3. Standardize Gender Values

df['Gender'] = df['Gender'].str.upper()

print("\nGender After Cleaning:")
print(df['Gender'].unique())
# Out:
# Gender After Cleaning:
# <StringArray>
# ['F', 'M', nan]
# Length: 3, dtype: str

# %%
#4. Statistical Summary

print("\nStatistical Summary")

summary = df.describe()

print(summary)
# Out:
# Statistical Summary
#         Unnamed: 0     Visit_ID    Patient_ID          AGE         Urea  \
# count  1009.000000  1009.000000  1.009000e+03  1008.000000  1008.000000
# mean    504.000000   338.166501  2.717468e+05    53.596230     5.132979
# std     291.417513   239.479644  3.365681e+06     8.743882     2.930873
# min       0.000000     1.000000  1.230000e+02    25.000000     0.500000
# 25%     252.000000   126.000000  2.406400e+04    51.000000     3.700000
# 50%     504.000000   294.000000  3.439900e+04    55.000000     4.600000
# 75%     756.000000   547.000000  4.539100e+04    59.000000     5.700000
# max    1008.000000   800.000000  7.543566e+07    79.000000    38.900000
#
#                 Cr        HbA1c         Chol           TG          HDL  \
# count  1007.000000  1006.000000  1007.000000  1007.000000  1008.000000
# mean     68.938431     8.281372     4.862483     2.346783     1.202728
# std      59.815673     2.534861     1.298665     1.396438     0.658038
# ...

# %%
#5. Box Plot for Numerical Columns

import matplotlib.pyplot as plt

plt.figure(figsize=(15,6))

df.select_dtypes(include=['number']).boxplot()

plt.title("Box Plot of Numerical Columns")

plt.xticks(rotation=45)

plt.show()

# %%
#print("\nMissing Values")

print(df.isnull().sum())
# Out:
# Unnamed: 0    0
# Visit_ID      0
# Patient_ID    0
# Gender        3
# AGE           1
# Urea          1
# Cr            2
# HbA1c         3
# Chol          2
# TG            2
# HDL           1
# LDL           2
# VLDL          1
# BMI           0
# CLASS         0
# dtype: int64

# %%
#7. Impute Missing Values Numerical Columns

num_cols = df.select_dtypes(include=['number']).columns

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
#8. Verify Missing Values Removed

print("\nMissing Values After Imputation")

print(df.isnull().sum())
# Out:
# Missing Values After Imputation
# Unnamed: 0    0
# Visit_ID      0
# Patient_ID    0
# Gender        3
# AGE           0
# Urea          0
# Cr            0
# HbA1c         0
# Chol          0
# TG            0
# HDL           0
# LDL           0
# VLDL          0
# BMI           0
# CLASS         0
# dtype: int64

# %%
#9. Check Duplicate Rows

duplicates = df.duplicated().sum()

print("\nDuplicate Rows:", duplicates)
# Out:
# Duplicate Rows: 0

# %%
#10. Remove Duplicates

df.drop_duplicates(inplace=True)
print("\nShape After Removing Duplicates")
print(df.shape)
# Out:
# Shape After Removing Duplicates
# (1009, 15)

# %%
# Check most frequent value
print(df['Gender'].mode())

# Fill missing Gender values
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])

# Verify again
print(df.isnull().sum())
# Out:
# 0    M
# Name: Gender, dtype: str
# Unnamed: 0    0
# Visit_ID      0
# Patient_ID    0
# Gender        0
# AGE           0
# Urea          0
# Cr            0
# HbA1c         0
# Chol          0
# TG            0
# HDL           0
# LDL           0
# VLDL          0
# BMI           0
# CLASS         0
# dtype: int64

# %%
#Filter Outliers in Cr (Creatinine)
#Calculate 99.5th Percentile

# %%
lipid_cols = ['LDL','VLDL','HDL','TG','Chol']
df_before = df.copy()
df_before[lipid_cols].boxplot(figsize=(10,5))
plt.title("Before Outlier Removal")
plt.show()

# %%
cr_threshold = df['Cr'].quantile(0.995)

print("Cr Threshold:", cr_threshold)
df = df[df['Cr'] <= cr_threshold]

print(df.shape)
# Out:
# Cr Threshold: 401.0
# (1003, 15)

# %% [markdown]
# For the Creatinine column, I used the 99.5th percentile threshold as specified in the assignment. Values above 343.66 were considered extreme and removed. This reduced the dataset size from 1009 to 999 records."

# %%
df[lipid_cols].boxplot(figsize=(10,5))
plt.title("After Outlier Removal")
plt.show()

# %%
#Urea Column
urea_threshold = df['Urea'].quantile(0.999)
print("Urea Threshold:", urea_threshold)
df = df[df['Urea'] <= urea_threshold]
print("Shape after Urea filtering:")
print(df.shape)
# Out:
# Urea Threshold: 26.424999999999407
# Shape after Urea filtering:
# (998, 15)

# %% [markdown]
# What happened?
# Before Urea filtering:
# (999, 15)
# After Urea filtering:
# (998, 15)
# So only 1 record was removed because its Urea value was greater than 26.425.

# %%
#Final Part: Lipid Columns
lipid_cols = ['LDL', 'VLDL', 'HDL', 'TG', 'Chol']

for col in lipid_cols:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower) & (df[col] <= upper)]

print("Final Shape:")
print(df.shape)
# Out:
# Final Shape:
# (813, 15)

# %% [markdown]
# Feature Engineering (Gender Encoding)

# %%
#Gender column contains:
#F M

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Gender'] = le.fit_transform(df['Gender'])

print(df['Gender'].head())
# Out:
# 1    1
# 4    1
# 5    0
# 6    0
# 7    1
# Name: Gender, dtype: int64

# %%
#Feature Scaling
#Scale columns such as Patient_ID, AGE, BMI, Cr

# %%
df[['Patient_ID','AGE','BMI','Cr']].hist(figsize=(10,5))
plt.suptitle("Before Scaling")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scale_cols = ['Patient_ID', 'AGE', 'BMI', 'Cr']

df[scale_cols] = scaler.fit_transform(df[scale_cols])

print(df[scale_cols].head())
# Out:
#    Patient_ID       AGE       BMI        Cr
# 1   -0.111255 -3.250125 -1.310213 -0.045079
# 4   -0.111250 -2.430064 -1.734310 -0.603013
# 5   -0.111248 -1.024247 -1.734310 -1.370172
# 6   -0.111246 -0.438489 -1.098165 -0.463529
# 7   -0.111241 -0.672792 -1.098165 -0.568142

# %%
scaled_df = pd.DataFrame(df[['Patient_ID','AGE','BMI','Cr']])

scaled_df.hist(figsize=(10,5))
plt.suptitle("After Scaling")
plt.show()
